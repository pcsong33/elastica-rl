# %%
D = {'spam':4, 'eggs':4, 'cool':'cool'}

# %%
D['spam']
# Out:
# 4

# %%
year = 3
age = 5

# %%
print(year + age)
# Out:
# 8

# %%
print(year, '\t',age)
# Out:
# 3 	 5

# %%
table = {'holy': 1982, "star": 2345, "trek": 2341}

# %%
for i in table:
    if
